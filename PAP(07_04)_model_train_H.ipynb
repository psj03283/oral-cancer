# %% [markdown]
# ## **Import Library**

# %%
# !pip install -q tensorflow
# !pip install efficientnet
# !pip install tensorflow_addons
# Out:
# Collecting efficientnet
#   Downloading efficientnet-1.1.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from efficientnet)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from efficientnet) (0.25.2)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.11/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (2.0.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.14.0)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->efficientnet) (1.15.3)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image->efficientnet) (3.5)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image->efficientnet) (11.2.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->efficientnet) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->efficientnet) (2025.6.11)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image->efficientnet) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->efficientnet) (0.4)
# Downloading efficientnet-1.1.1-py3-none-any.whl (18 kB)
# Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: keras-applications, efficientnet
# Successfully installed efficientnet-1.1.1 keras-applications-1.0.8
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow_addons) (24.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Downloading tensorflow_addons-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 34.9 MB/s eta 0:00:00
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.4.4
#     Uninstalling typeguard-4.4.4:
#       Successfully uninstalled typeguard-4.4.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# inflect 7.5.0 requires typeguard>=4.0.1, but you have typeguard 2.13.3 which is incompatible.
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3

# %%
# !pip install keras-metrics
# Out:
# Collecting keras-metrics
#   Downloading keras_metrics-1.1.0-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: Keras>=2.1.5 in /usr/local/lib/python3.11/dist-packages (from keras-metrics) (3.8.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from Keras>=2.1.5->keras-metrics) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from Keras>=2.1.5->keras-metrics) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from Keras>=2.1.5->keras-metrics) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from Keras>=2.1.5->keras-metrics) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from Keras>=2.1.5->keras-metrics) (3.14.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from Keras>=2.1.5->keras-metrics) (0.16.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from Keras>=2.1.5->keras-metrics) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from Keras>=2.1.5->keras-metrics) (24.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from optree->Keras>=2.1.5->keras-metrics) (4.14.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->Keras>=2.1.5->keras-metrics) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->Keras>=2.1.5->keras-metrics) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->Keras>=2.1.5->keras-metrics) (0.1.2)
# Downloading keras_metrics-1.1.0-py2.py3-none-any.whl (5.6 kB)
# Installing collected packages: keras-metrics
# Successfully installed keras-metrics-1.1.0

# %%
import tensorflow as tf

# %%
from tqdm import tqdm_notebook
ram=[]
for i in tqdm_notebook(range(100)):
  ram.append("randomword"*i)
# Out:
# /tmp/ipython-input-4-2252751400.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(100)):
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
from tensorflow import keras
from tensorflow.keras import layers

import matplotlib.pyplot as plt
import numpy as np
import os
import time
import os, glob, cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#from tensorflow.python.keras.utils import get_custom_objects
import efficientnet.tfkeras as efn
from tqdm import tqdm
#import tensorflow_addons as tfa
import openpyxl

# %%
SEED = 42
def seed_everything(seed):
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)

seed_everything(SEED)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !apt-get install fonts-crosextra-carlito
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Suggested packages:
#   fonts-crosextra-caladea
# The following NEW packages will be installed:
#   fonts-crosextra-carlito
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 743 kB of archives.
# After this operation, 2,798 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-crosextra-carlito all 20130920-1.1 [743 kB]
# Fetched 743 kB in 2s (472 kB/s)
# Selecting previously unselected package fonts-crosextra-carlito.
# (Reading database ... 126308 files and directories currently installed.)
# Preparing to unpack .../fonts-crosextra-carlito_20130920-1.1_all.deb ...
# Unpacking fonts-crosextra-carlito (20130920-1.1) ...
# Setting up fonts-crosextra-carlito (20130920-1.1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %% [markdown]
# ##**Training Data**

# %%
SEED = 42
EPOCHS = 50
BATCH_SIZE = 16
IMG_HEIGHT = 512
IMG_WIDTH = 512

# %%
import keras_metrics as km

# %%
os.makedirs("/content/drive/My Drive/pap_smear/metrics", exist_ok=True)
os.makedirs("/content/drive/My Drive/pap_smear/preds", exist_ok=True)
os.makedirs("/content/drive/My Drive/pap_smear/models", exist_ok=True)

# %%
import os
import glob
import numpy as np
import tensorflow as tf
import cv2
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, roc_auc_score
import pandas as pd

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
import efficientnet.tfkeras as efn

# -----------------------------
# ✅ Data pipeline helpers
# -----------------------------
def parse_function(file_path, label):
    image = tf.io.read_file(file_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [512, 512])
    image = image / 255.0
    return image, label

def numpy_rotate(image):
    image = image.numpy()
    angle = np.random.uniform(-10, 10)
    h, w = image.shape[:2]
    M = cv2.getRotationMatrix2D((w/2, h/2), angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_LINEAR, borderMode=cv2.BORDER_REFLECT_101)
    return rotated.astype(np.float32)

def augment_function(image, label):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    do_rotate = tf.less(tf.random.uniform([], 0, 1.0), 0.5)

    def _rotate():
        rotated = tf.py_function(func=numpy_rotate, inp=[image], Tout=tf.float32)
        rotated.set_shape(image.shape)  # Very important!
        return rotated

    image = tf.cond(
        do_rotate,
        _rotate,
        lambda: image
    )

    image = tf.image.random_brightness(image, max_delta=0.1)
    return image, label

# -----------------------------
# ✅ Build your model
# -----------------------------
def build_model(img_height, img_width, n_channels):
    inp = Input(shape=(img_height, img_width, n_channels))
    base = efn.EfficientNetB0(
        input_shape=(img_height, img_width, n_channels),
        weights='imagenet',
        include_top=False
    )
    x = base(inp)
    x = GlobalAveragePooling2D()(x)
    out = Dense(4, activation='softmax')(x)
    model = Model(inputs=inp, outputs=out)
    return model

# -----------------------------
# ✅ Custom MetricsLogger callback (Option A)
# -----------------------------
class MetricsLogger(tf.keras.callbacks.Callback):
    def __init__(self, val_ds, val_labels, class_names, fold, out_csv):
        super(MetricsLogger, self).__init__()
        self.val_ds = val_ds
        self.val_labels = val_labels
        self.class_names = class_names
        self.fold = fold
        self.out_csv = out_csv
        self.df = pd.DataFrame(columns=['epoch','fold','metric','class','value'])

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        val_loss = logs.get('val_loss')
        self.df.loc[len(self.df)] = [epoch+1, self.fold, 'loss', 'overall', val_loss]

        y_true = self.val_labels
        y_pred_probs = self.model.predict(self.val_ds, verbose=0)
        y_pred = np.argmax(y_pred_probs, axis=1)

        acc = accuracy_score(y_true, y_pred)
        self.df.loc[len(self.df)] = [epoch+1, self.fold, 'accuracy', 'overall', acc]

        precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, labels=np.arange(len(self.class_names)))
        for idx, class_name in enumerate(self.class_names):
            self.df.loc[len(self.df)] = [epoch+1, self.fold, 'precision', class_name, precision[idx]]
            self.df.loc[len(self.df)] = [epoch+1, self.fold, 'recall', class_name, recall[idx]]
            self.df.loc[len(self.df)] = [epoch+1, self.fold, 'f1', class_name, f1[idx]]

        precision_macro, recall_macro, f1_macro, _ = precision_recall_fscore_support(y_true, y_pred, average='macro')
        self.df.loc[len(self.df)] = [epoch+1, self.fold, 'precision', 'overall', precision_macro]
        self.df.loc[len(self.df)] = [epoch+1, self.fold, 'recall', 'overall', recall_macro]
        self.df.loc[len(self.df)] = [epoch+1, self.fold, 'f1', 'overall', f1_macro]

        y_true_onehot = tf.keras.utils.to_categorical(y_true, num_classes=len(self.class_names))
        try:
            roc_auc_macro = roc_auc_score(y_true_onehot, y_pred_probs, average='macro', multi_class='ovr')
            self.df.loc[len(self.df)] = [epoch+1, self.fold, 'roc_auc', 'overall', roc_auc_macro]
            for idx, class_name in enumerate(self.class_names):
                roc_auc_class = roc_auc_score(y_true_onehot[:, idx], y_pred_probs[:, idx])
                self.df.loc[len(self.df)] = [epoch+1, self.fold, 'roc_auc', class_name, roc_auc_class]
        except:
            print(f"⚠️ Skipped ROC AUC at epoch {epoch+1} due to lack of class variation.")

        self.df.to_csv(self.out_csv, index=False)

    def on_train_end(self, logs=None):
        # ✅ Final predictions for McNemar's test
        y_true = self.val_labels
        y_pred_probs = self.model.predict(self.val_ds, verbose=0)
        y_pred = np.argmax(y_pred_probs, axis=1)

        val_preds_df = pd.DataFrame({
            'index': np.arange(len(y_true)),
            'true_label': y_true,
            'pred_label': y_pred
        })

        val_preds_df.to_csv(
            f'/content/drive/My Drive/pap_smear/preds/fold{self.fold}_preds_H.csv',
            index=False
        )
        print(f"✅ Saved final val predictions for fold {self.fold}")

# -----------------------------
# ✅ Loop over folds
# -----------------------------
base_path = "/content/drive/My Drive/pap_smear/folds"
class_names = ['NILM', 'LSIL', 'HSIL', 'SCC']

BUFFER_SIZE = 1000
BATCH_SIZE = 16

for fold in range(1, 5):
    print(f"\n📂 Starting Fold {fold}")

    train_paths, train_labels = [], []
    val_paths, val_labels = [], []

    for class_label in ['0', '1', '2', '3']:
        train_glob = glob.glob(os.path.join(base_path, f"fold{fold}_H/train/{class_label}/*"))
        val_glob = glob.glob(os.path.join(base_path, f"fold{fold}_H/val/{class_label}/*"))
        train_paths.extend(train_glob)
        val_paths.extend(val_glob)
        train_labels.extend([int(class_label)] * len(train_glob))
        val_labels.extend([int(class_label)] * len(val_glob))

    train_ds = (
        tf.data.Dataset.from_tensor_slices((train_paths, train_labels))
        .shuffle(BUFFER_SIZE)
        .map(parse_function, num_parallel_calls=tf.data.AUTOTUNE)
        .map(augment_function, num_parallel_calls=tf.data.AUTOTUNE)
        .batch(BATCH_SIZE)
        .prefetch(tf.data.AUTOTUNE)
    )

    val_ds = (
        tf.data.Dataset.from_tensor_slices((val_paths, val_labels))
        .map(parse_function, num_parallel_calls=tf.data.AUTOTUNE)
        .batch(BATCH_SIZE)
        .prefetch(tf.data.AUTOTUNE)
    )

    model = build_model(512, 512, 3)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-7, verbose=1)
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
    metrics_logger = MetricsLogger(
        val_ds=val_ds,
        val_labels=np.array(val_labels),
        class_names=class_names,
        fold=fold,
        out_csv = f"/content/drive/My Drive/pap_smear/metrics/metrics_fold{fold}_H.csv"
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=30,
        callbacks=[reduce_lr, early_stop, metrics_logger],
        verbose=1
    )

    model.save(f"/content/drive/My Drive/pap_smear/models/model_fold{fold}_H.h5")
    print(f"✅ Finished Fold {fold}")
# Out:
# 📂 Starting Fold 1
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b0_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 16804768/16804768 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 211s 3s/step - accuracy: 0.4592 - loss: 1.2862 - val_accuracy: 0.4357 - val_loss: 1.3354 - learning_rate: 1.0000e-05
# Epoch 2/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 241ms/step - accuracy: 0.7072 - loss: 1.1006 - val_accuracy: 0.3320 - val_loss: 1.4453 - learning_rate: 1.0000e-05
# Epoch 3/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 241ms/step - accuracy: 0.8049 - loss: 0.9065 - val_accuracy: 0.2863 - val_loss: 3.6990 - learning_rate: 1.0000e-05
# Epoch 4/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.8425 - loss: 0.7711
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.8423 - loss: 0.7705 - val_accuracy: 0.4108 - val_loss: 7.5879 - learning_rate: 1.0000e-05
# Epoch 5/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 243ms/step - accuracy: 0.8483 - loss: 0.6727 - val_accuracy: 0.4772 - val_loss: 3.1127 - learning_rate: 5.0000e-06
# Epoch 6/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.8498 - loss: 0.6227 - val_accuracy: 0.5021 - val_loss: 1.3778 - learning_rate: 5.0000e-06
# Epoch 7/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 243ms/step - accuracy: 0.8661 - loss: 0.5899 - val_accuracy: 0.6100 - val_loss: 1.0540 - learning_rate: 5.0000e-06
# Epoch 8/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 243ms/step - accuracy: 0.8651 - loss: 0.5370 - val_accuracy: 0.7635 - val_loss: 0.9211 - learning_rate: 5.0000e-06
# Epoch 9/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 242ms/step - accuracy: 0.8717 - loss: 0.5171 - val_accuracy: 0.8008 - val_loss: 0.7486 - learning_rate: 5.0000e-06
# Epoch 10/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 240ms/step - accuracy: 0.8771 - loss: 0.4724 - val_accuracy: 0.8050 - val_loss: 0.6242 - learning_rate: 5.0000e-06
# Epoch 11/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 242ms/step - accuracy: 0.8755 - loss: 0.4414 - val_accuracy: 0.8091 - val_loss: 0.5550 - learning_rate: 5.0000e-06
# Epoch 12/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 241ms/step - accuracy: 0.8820 - loss: 0.4169 - val_accuracy: 0.8216 - val_loss: 0.5008 - learning_rate: 5.0000e-06
# Epoch 13/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 242ms/step - accuracy: 0.8752 - loss: 0.4156 - val_accuracy: 0.8340 - val_loss: 0.4645 - learning_rate: 5.0000e-06
# Epoch 14/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 240ms/step - accuracy: 0.9118 - loss: 0.3582 - val_accuracy: 0.8423 - val_loss: 0.4205 - learning_rate: 5.0000e-06
# Epoch 15/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 242ms/step - accuracy: 0.9096 - loss: 0.3462 - val_accuracy: 0.8548 - val_loss: 0.3734 - learning_rate: 5.0000e-06
# Epoch 16/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 242ms/step - accuracy: 0.9015 - loss: 0.3458 - val_accuracy: 0.9004 - val_loss: 0.3180 - learning_rate: 5.0000e-06
# Epoch 17/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 240ms/step - accuracy: 0.8931 - loss: 0.3559 - val_accuracy: 0.9170 - val_loss: 0.2749 - learning_rate: 5.0000e-06
# Epoch 18/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.8868 - loss: 0.3381 - val_accuracy: 0.9129 - val_loss: 0.2513 - learning_rate: 5.0000e-06
# Epoch 19/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.9044 - loss: 0.2850 - val_accuracy: 0.9212 - val_loss: 0.2237 - learning_rate: 5.0000e-06
# Epoch 20/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 240ms/step - accuracy: 0.9031 - loss: 0.3061 - val_accuracy: 0.9212 - val_loss: 0.2037 - learning_rate: 5.0000e-06
# Epoch 21/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 241ms/step - accuracy: 0.9184 - loss: 0.2947 - val_accuracy: 0.9336 - val_loss: 0.1900 - learning_rate: 5.0000e-06
# Epoch 22/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 241ms/step - accuracy: 0.9170 - loss: 0.2878 - val_accuracy: 0.9336 - val_loss: 0.1755 - learning_rate: 5.0000e-06
# Epoch 23/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 243ms/step - accuracy: 0.9230 - loss: 0.2584 - val_accuracy: 0.9378 - val_loss: 0.1668 - learning_rate: 5.0000e-06
# Epoch 24/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 242ms/step - accuracy: 0.9088 - loss: 0.2723 - val_accuracy: 0.9461 - val_loss: 0.1581 - learning_rate: 5.0000e-06
# Epoch 25/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 238ms/step - accuracy: 0.9448 - loss: 0.2339 - val_accuracy: 0.9461 - val_loss: 0.1544 - learning_rate: 5.0000e-06
# Epoch 26/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 240ms/step - accuracy: 0.9295 - loss: 0.2336 - val_accuracy: 0.9419 - val_loss: 0.1513 - learning_rate: 5.0000e-06
# Epoch 27/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 241ms/step - accuracy: 0.9237 - loss: 0.2351 - val_accuracy: 0.9585 - val_loss: 0.1452 - learning_rate: 5.0000e-06
# Epoch 28/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 241ms/step - accuracy: 0.9184 - loss: 0.2351 - val_accuracy: 0.9502 - val_loss: 0.1437 - learning_rate: 5.0000e-06
# Epoch 29/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 241ms/step - accuracy: 0.9650 - loss: 0.1914 - val_accuracy: 0.9544 - val_loss: 0.1355 - learning_rate: 5.0000e-06
# Epoch 30/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 240ms/step - accuracy: 0.9431 - loss: 0.1887 - val_accuracy: 0.9544 - val_loss: 0.1295 - learning_rate: 5.0000e-06
# Restoring model weights from the end of the best epoch: 30.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Saved final val predictions for fold 1
# ✅ Finished Fold 1
#
# 📂 Starting Fold 2
# Epoch 1/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 174s 2s/step - accuracy: 0.1472 - loss: 1.5991 - val_accuracy: 0.5062 - val_loss: 1.2678 - learning_rate: 1.0000e-05
# Epoch 2/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 237ms/step - accuracy: 0.4398 - loss: 1.3013 - val_accuracy: 0.3485 - val_loss: 1.4930 - learning_rate: 1.0000e-05
# Epoch 3/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 240ms/step - accuracy: 0.7551 - loss: 1.0762 - val_accuracy: 0.3776 - val_loss: 6.3873 - learning_rate: 1.0000e-05
# Epoch 4/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8477 - loss: 0.9032
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 237ms/step - accuracy: 0.8473 - loss: 0.9017 - val_accuracy: 0.3734 - val_loss: 11.9406 - learning_rate: 1.0000e-05
# Epoch 5/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 237ms/step - accuracy: 0.8723 - loss: 0.7360 - val_accuracy: 0.4315 - val_loss: 5.8596 - learning_rate: 5.0000e-06
# Epoch 6/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 237ms/step - accuracy: 0.8758 - loss: 0.6943 - val_accuracy: 0.4689 - val_loss: 3.5294 - learning_rate: 5.0000e-06
# Epoch 7/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.8535 - loss: 0.6392 - val_accuracy: 0.7801 - val_loss: 0.9230 - learning_rate: 5.0000e-06
# Epoch 8/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 238ms/step - accuracy: 0.8441 - loss: 0.6256 - val_accuracy: 0.8465 - val_loss: 0.7805 - learning_rate: 5.0000e-06
# Epoch 9/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 240ms/step - accuracy: 0.8888 - loss: 0.5271 - val_accuracy: 0.8631 - val_loss: 0.6299 - learning_rate: 5.0000e-06
# Epoch 10/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 240ms/step - accuracy: 0.8833 - loss: 0.4882 - val_accuracy: 0.8340 - val_loss: 0.5517 - learning_rate: 5.0000e-06
# Epoch 11/30
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 241ms/step - accuracy: 0.9017 - loss: 0.4481 - val_accuracy: 0.8340 - val_loss: 0.5133 - learning_rate: 5.0000e-06
# Epoch 12/30
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.8678 - loss: 0.4731 - val_accuracy: 0.8423 - val_loss: 0.4788 - learning_rate: 5.0000e-06
# Epoch 13/30
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.8757 - loss: 0.4059 - val_accuracy: 0.8465 - val_loss: 0.4455 - learning_rate: 5.0000e-06
# Epoch 14/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 238ms/step - accuracy: 0.8728 - loss: 0.4334 - val_accuracy: 0.8589 - val_loss: 0.4132 - learning_rate: 5.0000e-06
# Epoch 15/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 238ms/step - accuracy: 0.8747 - loss: 0.3761 - val_accuracy: 0.8921 - val_loss: 0.3636 - learning_rate: 5.0000e-06
# Epoch 16/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.9198 - loss: 0.3312 - val_accuracy: 0.9170 - val_loss: 0.3172 - learning_rate: 5.0000e-06
# Epoch 17/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 240ms/step - accuracy: 0.8675 - loss: 0.3530 - val_accuracy: 0.9336 - val_loss: 0.2765 - learning_rate: 5.0000e-06
# Epoch 18/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 241ms/step - accuracy: 0.9043 - loss: 0.3247 - val_accuracy: 0.9378 - val_loss: 0.2347 - learning_rate: 5.0000e-06
# Epoch 19/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.9017 - loss: 0.3333 - val_accuracy: 0.9378 - val_loss: 0.2169 - learning_rate: 5.0000e-06
# Epoch 20/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.8841 - loss: 0.3161 - val_accuracy: 0.9295 - val_loss: 0.2053 - learning_rate: 5.0000e-06
# Epoch 21/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 238ms/step - accuracy: 0.9173 - loss: 0.2654 - val_accuracy: 0.9253 - val_loss: 0.1949 - learning_rate: 5.0000e-06
# Epoch 22/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 238ms/step - accuracy: 0.9265 - loss: 0.2519 - val_accuracy: 0.9419 - val_loss: 0.1833 - learning_rate: 5.0000e-06
# Epoch 23/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.9033 - loss: 0.2763 - val_accuracy: 0.9461 - val_loss: 0.1751 - learning_rate: 5.0000e-06
# Epoch 24/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.8852 - loss: 0.2954 - val_accuracy: 0.9461 - val_loss: 0.1689 - learning_rate: 5.0000e-06
# Epoch 25/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.9074 - loss: 0.2733 - val_accuracy: 0.9502 - val_loss: 0.1579 - learning_rate: 5.0000e-06
# Epoch 26/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 240ms/step - accuracy: 0.8939 - loss: 0.2886 - val_accuracy: 0.9544 - val_loss: 0.1511 - learning_rate: 5.0000e-06
# Epoch 27/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 241ms/step - accuracy: 0.9396 - loss: 0.2207 - val_accuracy: 0.9544 - val_loss: 0.1455 - learning_rate: 5.0000e-06
# Epoch 28/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.9142 - loss: 0.2442 - val_accuracy: 0.9627 - val_loss: 0.1419 - learning_rate: 5.0000e-06
# Epoch 29/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 240ms/step - accuracy: 0.9392 - loss: 0.2081 - val_accuracy: 0.9627 - val_loss: 0.1378 - learning_rate: 5.0000e-06
# Epoch 30/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 236ms/step - accuracy: 0.9446 - loss: 0.2157 - val_accuracy: 0.9627 - val_loss: 0.1322 - learning_rate: 5.0000e-06
# Restoring model weights from the end of the best epoch: 30.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Saved final val predictions for fold 2
# ✅ Finished Fold 2
#
# 📂 Starting Fold 3
# Epoch 1/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - accuracy: 0.3601 - loss: 1.3345 - val_accuracy: 0.2208 - val_loss: 1.3745 - learning_rate: 1.0000e-05
# Epoch 2/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 237ms/step - accuracy: 0.6995 - loss: 1.1067 - val_accuracy: 0.2000 - val_loss: 1.8701 - learning_rate: 1.0000e-05
# Epoch 3/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 240ms/step - accuracy: 0.7971 - loss: 0.9262 - val_accuracy: 0.2417 - val_loss: 3.5518 - learning_rate: 1.0000e-05
# Epoch 4/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8297 - loss: 0.7710
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 236ms/step - accuracy: 0.8300 - loss: 0.7697 - val_accuracy: 0.3000 - val_loss: 7.3826 - learning_rate: 1.0000e-05
# Epoch 5/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 235ms/step - accuracy: 0.8395 - loss: 0.6488 - val_accuracy: 0.3333 - val_loss: 3.9248 - learning_rate: 5.0000e-06
# Epoch 6/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 238ms/step - accuracy: 0.8559 - loss: 0.5983 - val_accuracy: 0.4708 - val_loss: 1.9180 - learning_rate: 5.0000e-06
# Epoch 7/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 240ms/step - accuracy: 0.8609 - loss: 0.5752 - val_accuracy: 0.5667 - val_loss: 1.0344 - learning_rate: 5.0000e-06
# Epoch 8/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 237ms/step - accuracy: 0.8602 - loss: 0.5093 - val_accuracy: 0.7167 - val_loss: 0.8555 - learning_rate: 5.0000e-06
# Epoch 9/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 238ms/step - accuracy: 0.8729 - loss: 0.4786 - val_accuracy: 0.8333 - val_loss: 0.5966 - learning_rate: 5.0000e-06
# Epoch 10/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 240ms/step - accuracy: 0.8908 - loss: 0.4428 - val_accuracy: 0.8625 - val_loss: 0.4847 - learning_rate: 5.0000e-06
# Epoch 11/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 237ms/step - accuracy: 0.8713 - loss: 0.4219 - val_accuracy: 0.8917 - val_loss: 0.4323 - learning_rate: 5.0000e-06
# Epoch 12/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.8859 - loss: 0.4003 - val_accuracy: 0.9042 - val_loss: 0.4067 - learning_rate: 5.0000e-06
# Epoch 13/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 238ms/step - accuracy: 0.8832 - loss: 0.4096 - val_accuracy: 0.9125 - val_loss: 0.3775 - learning_rate: 5.0000e-06
# Epoch 14/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.8966 - loss: 0.3415 - val_accuracy: 0.9250 - val_loss: 0.3443 - learning_rate: 5.0000e-06
# Epoch 15/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 241ms/step - accuracy: 0.8752 - loss: 0.3610 - val_accuracy: 0.9333 - val_loss: 0.3115 - learning_rate: 5.0000e-06
# Epoch 16/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 240ms/step - accuracy: 0.8969 - loss: 0.3254 - val_accuracy: 0.9500 - val_loss: 0.2740 - learning_rate: 5.0000e-06
# Epoch 17/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.8852 - loss: 0.3310 - val_accuracy: 0.9542 - val_loss: 0.2485 - learning_rate: 5.0000e-06
# Epoch 18/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 238ms/step - accuracy: 0.8726 - loss: 0.3414 - val_accuracy: 0.9458 - val_loss: 0.2270 - learning_rate: 5.0000e-06
# Epoch 19/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.9057 - loss: 0.3118 - val_accuracy: 0.9375 - val_loss: 0.2061 - learning_rate: 5.0000e-06
# Epoch 20/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 238ms/step - accuracy: 0.9231 - loss: 0.2638 - val_accuracy: 0.9458 - val_loss: 0.1879 - learning_rate: 5.0000e-06
# Epoch 21/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 238ms/step - accuracy: 0.9141 - loss: 0.2654 - val_accuracy: 0.9667 - val_loss: 0.1699 - learning_rate: 5.0000e-06
# Epoch 22/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.9126 - loss: 0.2678 - val_accuracy: 0.9667 - val_loss: 0.1493 - learning_rate: 5.0000e-06
# Epoch 23/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.9370 - loss: 0.2263 - val_accuracy: 0.9833 - val_loss: 0.1416 - learning_rate: 5.0000e-06
# Epoch 24/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.8894 - loss: 0.2833 - val_accuracy: 0.9875 - val_loss: 0.1342 - learning_rate: 5.0000e-06
# Epoch 25/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 240ms/step - accuracy: 0.9002 - loss: 0.2898 - val_accuracy: 0.9917 - val_loss: 0.1277 - learning_rate: 5.0000e-06
# Epoch 26/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 238ms/step - accuracy: 0.9114 - loss: 0.2510 - val_accuracy: 0.9958 - val_loss: 0.1176 - learning_rate: 5.0000e-06
# Epoch 27/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 238ms/step - accuracy: 0.9215 - loss: 0.2227 - val_accuracy: 0.9958 - val_loss: 0.1123 - learning_rate: 5.0000e-06
# Epoch 28/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 238ms/step - accuracy: 0.9376 - loss: 0.2252 - val_accuracy: 0.9917 - val_loss: 0.1101 - learning_rate: 5.0000e-06
# Epoch 29/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.9146 - loss: 0.2491 - val_accuracy: 0.9958 - val_loss: 0.1056 - learning_rate: 5.0000e-06
# Epoch 30/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 238ms/step - accuracy: 0.9249 - loss: 0.2187 - val_accuracy: 0.9958 - val_loss: 0.1014 - learning_rate: 5.0000e-06
# Restoring model weights from the end of the best epoch: 30.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Saved final val predictions for fold 3
# ✅ Finished Fold 3
#
# 📂 Starting Fold 4
# Epoch 1/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - accuracy: 0.3316 - loss: 1.3645 - val_accuracy: 0.1625 - val_loss: 1.5554 - learning_rate: 1.0000e-05
# Epoch 2/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 240ms/step - accuracy: 0.6499 - loss: 1.1411 - val_accuracy: 0.1708 - val_loss: 1.6097 - learning_rate: 1.0000e-05
# Epoch 3/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 240ms/step - accuracy: 0.7834 - loss: 0.9522 - val_accuracy: 0.3250 - val_loss: 3.7750 - learning_rate: 1.0000e-05
# Epoch 4/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8649 - loss: 0.7712
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 237ms/step - accuracy: 0.8641 - loss: 0.7705 - val_accuracy: 0.3958 - val_loss: 6.9317 - learning_rate: 1.0000e-05
# Epoch 5/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 236ms/step - accuracy: 0.8380 - loss: 0.6654 - val_accuracy: 0.3708 - val_loss: 3.3359 - learning_rate: 5.0000e-06
# Epoch 6/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 238ms/step - accuracy: 0.8876 - loss: 0.5730 - val_accuracy: 0.3375 - val_loss: 1.4212 - learning_rate: 5.0000e-06
# Epoch 7/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 237ms/step - accuracy: 0.8728 - loss: 0.5576 - val_accuracy: 0.4917 - val_loss: 1.4847 - learning_rate: 5.0000e-06
# Epoch 8/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 237ms/step - accuracy: 0.8785 - loss: 0.5253 - val_accuracy: 0.6417 - val_loss: 1.1382 - learning_rate: 5.0000e-06
# Epoch 9/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 235ms/step - accuracy: 0.8810 - loss: 0.4793 - val_accuracy: 0.7958 - val_loss: 1.4879 - learning_rate: 5.0000e-06
# Epoch 10/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.8980 - loss: 0.4289 - val_accuracy: 0.8208 - val_loss: 0.9720 - learning_rate: 5.0000e-06
# Epoch 11/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 242ms/step - accuracy: 0.8633 - loss: 0.4720 - val_accuracy: 0.8583 - val_loss: 0.9301 - learning_rate: 5.0000e-06
# Epoch 12/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 236ms/step - accuracy: 0.8984 - loss: 0.3974 - val_accuracy: 0.8708 - val_loss: 0.4790 - learning_rate: 5.0000e-06
# Epoch 13/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.8853 - loss: 0.3899 - val_accuracy: 0.9000 - val_loss: 0.4251 - learning_rate: 5.0000e-06
# Epoch 14/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 238ms/step - accuracy: 0.9032 - loss: 0.3579 - val_accuracy: 0.8958 - val_loss: 0.3938 - learning_rate: 5.0000e-06
# Epoch 15/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 238ms/step - accuracy: 0.9121 - loss: 0.3430 - val_accuracy: 0.8958 - val_loss: 0.3621 - learning_rate: 5.0000e-06
# Epoch 16/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 237ms/step - accuracy: 0.9020 - loss: 0.3324 - val_accuracy: 0.9042 - val_loss: 0.3336 - learning_rate: 5.0000e-06
# Epoch 17/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 238ms/step - accuracy: 0.8984 - loss: 0.3407 - val_accuracy: 0.9208 - val_loss: 0.2933 - learning_rate: 5.0000e-06
# Epoch 18/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 237ms/step - accuracy: 0.8946 - loss: 0.3284 - val_accuracy: 0.9458 - val_loss: 0.2645 - learning_rate: 5.0000e-06
# Epoch 19/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 241ms/step - accuracy: 0.9148 - loss: 0.2773 - val_accuracy: 0.9333 - val_loss: 0.2374 - learning_rate: 5.0000e-06
# Epoch 20/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 240ms/step - accuracy: 0.8790 - loss: 0.3125 - val_accuracy: 0.9458 - val_loss: 0.2239 - learning_rate: 5.0000e-06
# Epoch 21/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 238ms/step - accuracy: 0.9120 - loss: 0.2882 - val_accuracy: 0.9458 - val_loss: 0.2126 - learning_rate: 5.0000e-06
# Epoch 22/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.9106 - loss: 0.2767 - val_accuracy: 0.9500 - val_loss: 0.1978 - learning_rate: 5.0000e-06
# Epoch 23/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.8975 - loss: 0.2833 - val_accuracy: 0.9542 - val_loss: 0.1908 - learning_rate: 5.0000e-06
# Epoch 24/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.9252 - loss: 0.2651 - val_accuracy: 0.9583 - val_loss: 0.1723 - learning_rate: 5.0000e-06
# Epoch 25/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.9244 - loss: 0.2502 - val_accuracy: 0.9625 - val_loss: 0.1649 - learning_rate: 5.0000e-06
# Epoch 26/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 237ms/step - accuracy: 0.9130 - loss: 0.2633 - val_accuracy: 0.9667 - val_loss: 0.1564 - learning_rate: 5.0000e-06
# Epoch 27/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 236ms/step - accuracy: 0.9225 - loss: 0.2292 - val_accuracy: 0.9625 - val_loss: 0.1584 - learning_rate: 5.0000e-06
# Epoch 28/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 241ms/step - accuracy: 0.9436 - loss: 0.2009 - val_accuracy: 0.9667 - val_loss: 0.1542 - learning_rate: 5.0000e-06
# Epoch 29/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 241ms/step - accuracy: 0.9244 - loss: 0.2495 - val_accuracy: 0.9708 - val_loss: 0.1484 - learning_rate: 5.0000e-06
# Epoch 30/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 237ms/step - accuracy: 0.9317 - loss: 0.1774 - val_accuracy: 0.9750 - val_loss: 0.1436 - learning_rate: 5.0000e-06
# Restoring model weights from the end of the best epoch: 30.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Saved final val predictions for fold 4
# ✅ Finished Fold 4

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib as mpl

# === ✅ Add Carlito font correctly ===
font_path = '/usr/share/fonts/truetype/crosextra/Carlito-Regular.ttf'
fm.fontManager.addfont(font_path)
mpl.rcParams['font.family'] = 'Carlito'

# === Load all folds ===
dfs = []
for fold in range(1, 5):
    df = pd.read_csv(f'/content/drive/My Drive/pap_smear/metrics/metrics_fold{fold}_H.csv')
    df['fold'] = fold
    dfs.append(df)

full_df = pd.concat(dfs, ignore_index=True)

# === Metrics you want ===
metrics = ['accuracy', 'f1', 'loss', 'roc_auc']

for metric in metrics:
    plt.figure(figsize=(8, 5))

    # Filter for overall only
    metric_df = full_df[(full_df['metric'] == metric) & (full_df['class'] == 'overall')]

    for fold in metric_df['fold'].unique():
        fold_df = metric_df[metric_df['fold'] == fold]
        plt.plot(fold_df['epoch'], fold_df['value'], label=f'Fold {fold}')

    plt.title(f'Validation {metric.capitalize()} Across Epochs', fontsize=14)
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel(metric.capitalize(), fontsize=12)
    plt.legend(title='Fold', fontsize=10)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib as mpl

# === ✅ Add Carlito font correctly ===
font_path = '/usr/share/fonts/truetype/crosextra/Carlito-Regular.ttf'
fm.fontManager.addfont(font_path)
mpl.rcParams['font.family'] = 'Carlito'

# === Load all folds ===
dfs = []
for fold in range(1, 5):
    df = pd.read_csv(f'/content/drive/My Drive/pap_smear/metrics/metrics_fold{fold}_H.csv')
    df['fold'] = fold
    dfs.append(df)

full_df = pd.concat(dfs, ignore_index=True)

# === Metric you want ===
metrics = ['accuracy', 'f1', 'loss', 'roc_auc']

# NYU purple color
nyu_purple = '#57068c'

for metric in metrics:
    plt.figure(figsize=(8, 5))

    metric_df = full_df[(full_df['metric'] == metric) & (full_df['class'] == 'overall')]
    mean_df = metric_df.groupby('epoch')['value'].mean().reset_index()

    plt.plot(
        mean_df['epoch'],
        mean_df['value'],
        '-',                  # solid line, no markers
        color=nyu_purple,
        label='Mean'
    )

    plt.title(f'Validation {metric.capitalize()} (Mean Across Folds)', fontsize=14)
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel(metric.capitalize(), fontsize=12)
    plt.legend(fontsize=10)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ##**Evaluation Metrics**

# %%
import pandas as pd

# === Load all metrics ===
dfs = []
for fold in range(1, 5):
    df = pd.read_csv(f'/content/drive/My Drive/pap_smear/metrics/metrics_fold{fold}_H.csv')
    df['fold'] = fold
    dfs.append(df)

full_df = pd.concat(dfs, ignore_index=True)

# === Filter only final epoch for each fold ===
# If you want best epoch per fold, you’d do:
# final_df = full_df.loc[full_df.groupby('fold')['epoch'].idxmax()]

# Here: get final epoch for each fold
fold_results = []

for fold in range(1, 5):
    fold_df = full_df[full_df['fold'] == fold]
    final_epoch = fold_df['epoch'].max()
    final_df = fold_df[fold_df['epoch'] == final_epoch]
    fold_results.append(final_df)

final_df = pd.concat(fold_results, ignore_index=True)

# === Keep only precision, recall, f1 for per-class ===
results = final_df[
    (final_df['metric'].isin(['precision', 'recall', 'f1'])) &
    (final_df['class'].isin(['NILM', 'LSIL', 'HSIL', 'SCC']))
]

# === Pivot to get [fold x metric] for each class ===
table = []
classes = ['NILM', 'LSIL', 'HSIL', 'SCC']
for class_name in classes:
    class_data = results[results['class'] == class_name].pivot(
        index='metric', columns='fold', values='value'
    )
    mean = class_data.mean(axis=1)
    std = class_data.std(axis=1)
    # You can skip std if you don’t want it
    table.append({
        'Class': class_name,
        'Precision': f"{mean['precision']:.5f}",
        'Recall': f"{mean['recall']:.5f}",
        'F1-score': f"{mean['f1']:.5f}",
        'Precision_std': f"{std['precision']:.5f}",
        'Recall_std': f"{std['recall']:.5f}",
        'F1-score_std': f"{std['f1']:.5f}"
    })

summary_df = pd.DataFrame(table)
print(summary_df)

# === Optional: save to CSV ===
summary_df.to_csv('/content/drive/My Drive/pap_smear/final_class_metrics_H.csv', index=False)
# Out:
#   Class Precision   Recall F1-score Precision_std Recall_std F1-score_std
# 0  NILM   0.99674  0.99837  0.99755       0.00376    0.00327      0.00313
# 1  LSIL   0.97500  1.00000  0.98714       0.03191    0.00000      0.01648
# 2  HSIL   0.94619  0.91326  0.92668       0.05847    0.09500      0.05905
# 3   SCC   0.84992  0.83918  0.83672       0.15202    0.13752      0.11860

# %%
import pandas as pd

# === Load all metrics ===
dfs = []
for fold in range(1, 5):  # fix range to 1-6 if you have 5 folds!
    df = pd.read_csv(f'/content/drive/My Drive/pap_smear/metrics/metrics_fold{fold}_H.csv')
    df['fold'] = fold
    dfs.append(df)

full_df = pd.concat(dfs, ignore_index=True)

# === Get final epoch for each fold ===
fold_results = []
for fold in range(1, 5):
    fold_df = full_df[full_df['fold'] == fold]
    final_epoch = fold_df['epoch'].max()
    final_df = fold_df[fold_df['epoch'] == final_epoch]
    fold_results.append(final_df)

final_df = pd.concat(fold_results, ignore_index=True)

# === Keep only per-class metrics ===
results = final_df[
    (final_df['metric'].isin(['precision', 'recall', 'f1'])) &
    (final_df['class'].isin(['NILM', 'LSIL', 'HSIL', 'SCC']))
]

# === Pivot, compute mean ± std, and format ===
table = []
classes = ['NILM', 'LSIL', 'HSIL', 'SCC']
for class_name in classes:
    class_data = results[results['class'] == class_name].pivot(
        index='metric', columns='fold', values='value'
    )
    mean = class_data.mean(axis=1)
    std = class_data.std(axis=1)

    table.append({
        'Class': class_name,
        'Precision': f"{mean['precision']:.3f} ± {std['precision']:.3f}",
        'Recall': f"{mean['recall']:.3f} ± {std['recall']:.3f}",
        'F1-score': f"{mean['f1']:.3f} ± {std['f1']:.3f}"
    })

summary_df = pd.DataFrame(table)
print(summary_df)

# === Optional: save for your paper ===
summary_df.to_csv('/content/drive/My Drive/pap_smear/final_class_metrics_formatted_H.csv', index=False)
# Out:
#   Class      Precision         Recall       F1-score
# 0  NILM  0.997 ± 0.004  0.998 ± 0.003  0.998 ± 0.003
# 1  LSIL  0.975 ± 0.032  1.000 ± 0.000  0.987 ± 0.016
# 2  HSIL  0.946 ± 0.058  0.913 ± 0.095  0.927 ± 0.059
# 3   SCC  0.850 ± 0.152  0.839 ± 0.138  0.837 ± 0.119

# %%
import pandas as pd

# === Load all folds ===
dfs = []
for fold in range(1, 5):   # ✅ use 1–5 for 4 folds!
    df = pd.read_csv(f'/content/drive/My Drive/pap_smear/metrics/metrics_fold{fold}_H.csv')
    df['fold'] = fold
    dfs.append(df)

full_df = pd.concat(dfs, ignore_index=True)

# === Filter for overall only at final epoch ===
overall_results = []
for fold in range(1, 5):   # ✅ 4 folds!
    fold_df = full_df[full_df['fold'] == fold]
    final_epoch = fold_df['epoch'].max()
    final_df = fold_df[
        (fold_df['epoch'] == final_epoch) &
        (fold_df['class'] == 'overall') &
        (fold_df['metric'].isin(['accuracy', 'loss', 'precision', 'recall', 'f1', 'roc_auc']))
    ]
    overall_results.append(final_df)

overall_df = pd.concat(overall_results, ignore_index=True)

# === Compute mean ± SD for each metric ===
overall_table = []
metrics = ['accuracy', 'loss', 'precision', 'recall', 'f1', 'roc_auc']
for metric in metrics:
    metric_vals = overall_df[overall_df['metric'] == metric]['value'].values
    mean_val = metric_vals.mean()
    std_val = metric_vals.std()
    overall_table.append({
        'Metric': metric.capitalize(),
        'Mean ± SD': f"{mean_val:.3f} ± {std_val:.3f}"
    })

summary_overall_df = pd.DataFrame(overall_table)

# ✅ Display
print(summary_overall_df)

# ✅ Optional: save
summary_overall_df.to_csv('/content/drive/My Drive/pap_smear/final_overall_metrics_formatted_H.csv', index=False)
# Out:
#       Metric      Mean ± SD
# 0   Accuracy  0.972 ± 0.016
# 1       Loss  0.127 ± 0.015
# 2  Precision  0.942 ± 0.038
# 3     Recall  0.938 ± 0.035
# 4         F1  0.937 ± 0.038
# 5    Roc_auc  0.996 ± 0.002

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

# === Settings ===
folds = [1, 2, 3, 4]
class_names = ['NILM', 'LSIL', 'HSIL', 'SCC']
n_classes = len(class_names)

# === Initialize total confusion matrix
cm_total = np.zeros((n_classes, n_classes), dtype=int)

# === Loop through folds and sum up
for fold in folds:
    df = pd.read_csv(f'/content/drive/My Drive/pap_smear/preds/fold{fold}_preds_H.csv')
    y_true = df['true_label']
    y_pred = df['pred_label']
    cm = confusion_matrix(y_true, y_pred, labels=range(n_classes))
    cm_total += cm

# === Display combined confusion matrix
ConfusionMatrixDisplay(cm_total, display_labels=class_names).plot(
    cmap=plt.cm.Blues, values_format='d'
)
plt.title("Confusion Matrix - All 4 Folds Combined (H)")
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix

folds = [1, 2, 3, 4]
class_names = ['NILM', 'LSIL', 'HSIL', 'SCC']
n_classes = len(class_names)

# === Store all folds ===
results = []

for fold in folds:
    df = pd.read_csv(f'/content/drive/My Drive/pap_smear/preds/fold{fold}_preds_H.csv')
    y_true = df['true_label']
    y_pred = df['pred_label']
    cm = confusion_matrix(y_true, y_pred, labels=range(n_classes))

    # Per class:
    for i, class_name in enumerate(class_names):
        TP = cm[i, i]
        FN = cm[i, :].sum() - TP
        FP = cm[:, i].sum() - TP
        TN = cm.sum() - (TP + FP + FN)

        sensitivity = TP / (TP + FN) if (TP + FN) > 0 else 0
        specificity = TN / (TN + FP) if (TN + FP) > 0 else 0

        results.append({
            'fold': fold,
            'class': class_name,
            'sensitivity': sensitivity,
            'specificity': specificity
        })

# === Make dataframe ===
sens_spec_df = pd.DataFrame(results)

print("\n🔍 Per class, per fold:")
print(sens_spec_df.head())

# === Compute mean ± SD across folds ===
summary = []
for class_name in class_names:
    class_df = sens_spec_df[sens_spec_df['class'] == class_name]

    sens_mean = class_df['sensitivity'].mean()
    sens_std = class_df['sensitivity'].std()

    spec_mean = class_df['specificity'].mean()
    spec_std = class_df['specificity'].std()

    summary.append({
        'class': class_name,
        'sensitivity': f"{sens_mean:.3f} ± {sens_std:.3f}",
        'specificity': f"{spec_mean:.3f} ± {spec_std:.3f}",
    })

summary_df = pd.DataFrame(summary)

print("\n✅ Mean ± SD across folds:")
print(summary_df)

# === Save if you want ===
sens_spec_df.to_csv('/content/drive/My Drive/pap_smear/sens_spec_per_fold_H.csv', index=False)
summary_df.to_csv('/content/drive/My Drive/pap_smear/sens_spec_mean_sd_H.csv', index=False)
# Out:
# 🔍 Per class, per fold:
#    fold class  sensitivity  specificity
# 0     1  NILM     1.000000     1.000000
# 1     1  LSIL     1.000000     0.995283
# 2     1  HSIL     0.775000     0.995025
# 3     1   SCC     0.894737     0.959459
# 4     2  NILM     1.000000     1.000000
#
# ✅ Mean ± SD across folds:
#   class    sensitivity    specificity
# 0  NILM  0.998 ± 0.003  0.994 ± 0.007
# 1  LSIL  1.000 ± 0.000  0.996 ± 0.005
# 2  HSIL  0.913 ± 0.095  0.989 ± 0.013
# 3   SCC  0.839 ± 0.138  0.985 ± 0.018

# %%
import pandas as pd
from sklearn.metrics import cohen_kappa_score

folds = [1, 2, 3, 4]

kappa_results = []

for fold in folds:
    df = pd.read_csv(f'/content/drive/My Drive/pap_smear/preds/fold{fold}_preds_H.csv')
    y_true = df['true_label']
    y_pred = df['pred_label']

    kappa = cohen_kappa_score(y_true, y_pred)
    kappa_results.append({'fold': fold, 'cohen_kappa': kappa})

kappa_df = pd.DataFrame(kappa_results)
print("\n✅ Cohen’s Kappa per fold:")
print(kappa_df)
# Out:
# ✅ Cohen’s Kappa per fold:
#    fold  cohen_kappa
# 0     1     0.917229
# 1     2     0.931750
# 2     3     0.992330
# 3     4     0.954080

# %%
mean_kappa = kappa_df['cohen_kappa'].mean()
std_kappa = kappa_df['cohen_kappa'].std()

print(f"\n✅ Overall Cohen’s Kappa: {mean_kappa:.3f} ± {std_kappa:.3f}")

# Save if you like
kappa_df.to_csv('/content/drive/My Drive/pap_smear/cohen_kappa_per_fold_H.csv', index=False)
with open('/content/drive/My Drive/pap_smear/cohen_kappa_summary_H.txt', 'w') as f:
    f.write(f"Cohen’s Kappa mean ± SD: {mean_kappa:.3f} ± {std_kappa:.3f}\n")
# Out:
# ✅ Overall Cohen’s Kappa: 0.949 ± 0.033

# %%
import numpy as np

dfs = []
for fold in folds:
    df = pd.read_csv(f'/content/drive/My Drive/pap_smear/preds/fold{fold}_preds_H.csv')
    dfs.append(df)

combined_df = pd.concat(dfs, ignore_index=True)
y_true_all = combined_df['true_label']
y_pred_all = combined_df['pred_label']

kappa_overall = cohen_kappa_score(y_true_all, y_pred_all)
print(f"\n✅ Cohen’s Kappa (all folds combined): {kappa_overall:.3f}")
# Out:
# ✅ Cohen’s Kappa (all folds combined): 0.949
