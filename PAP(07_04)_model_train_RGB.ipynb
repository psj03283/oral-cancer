# %% [markdown]
# <a href="https://colab.research.google.com/github/psj03283/oral-cancer/blob/main/PAP(07_04)_model_train_RGB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Import Library**

# %%
# !pip install -q tensorflow
# !pip install efficientnet
# !pip install tensorflow_addons
# Out:
# Collecting efficientnet
#   Downloading efficientnet-1.1.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from efficientnet)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from efficientnet) (0.25.2)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.11/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (2.0.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.14.0)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->efficientnet) (1.15.3)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image->efficientnet) (3.5)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image->efficientnet) (11.2.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->efficientnet) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->efficientnet) (2025.6.11)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image->efficientnet) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->efficientnet) (0.4)
# Downloading efficientnet-1.1.1-py3-none-any.whl (18 kB)
# Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 6.0 MB/s eta 0:00:00
# Installing collected packages: keras-applications, efficientnet
# Successfully installed efficientnet-1.1.1 keras-applications-1.0.8
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow_addons) (24.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Downloading tensorflow_addons-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 42.6 MB/s eta 0:00:00
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.4.4
#     Uninstalling typeguard-4.4.4:
#       Successfully uninstalled typeguard-4.4.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# inflect 7.5.0 requires typeguard>=4.0.1, but you have typeguard 2.13.3 which is incompatible.
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3

# %%
# !pip install keras-metrics
# Out:
# Collecting keras-metrics
#   Downloading keras_metrics-1.1.0-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: Keras>=2.1.5 in /usr/local/lib/python3.11/dist-packages (from keras-metrics) (3.8.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from Keras>=2.1.5->keras-metrics) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from Keras>=2.1.5->keras-metrics) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from Keras>=2.1.5->keras-metrics) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from Keras>=2.1.5->keras-metrics) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from Keras>=2.1.5->keras-metrics) (3.14.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from Keras>=2.1.5->keras-metrics) (0.16.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from Keras>=2.1.5->keras-metrics) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from Keras>=2.1.5->keras-metrics) (24.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from optree->Keras>=2.1.5->keras-metrics) (4.14.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->Keras>=2.1.5->keras-metrics) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->Keras>=2.1.5->keras-metrics) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->Keras>=2.1.5->keras-metrics) (0.1.2)
# Downloading keras_metrics-1.1.0-py2.py3-none-any.whl (5.6 kB)
# Installing collected packages: keras-metrics
# Successfully installed keras-metrics-1.1.0

# %%
import tensorflow as tf

# %%
from tqdm import tqdm_notebook
ram=[]
for i in tqdm_notebook(range(100)):
  ram.append("randomword"*i)
# Out:
# /tmp/ipython-input-4-2252751400.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(100)):
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
from tensorflow import keras
from tensorflow.keras import layers

import matplotlib.pyplot as plt
import numpy as np
import os
import time
import os, glob, cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#from tensorflow.python.keras.utils import get_custom_objects
import efficientnet.tfkeras as efn
from tqdm import tqdm
#import tensorflow_addons as tfa
import openpyxl

# %%
SEED = 42
def seed_everything(seed):
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)

seed_everything(SEED)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !apt-get install fonts-crosextra-carlito
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Suggested packages:
#   fonts-crosextra-caladea
# The following NEW packages will be installed:
#   fonts-crosextra-carlito
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 743 kB of archives.
# After this operation, 2,798 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-crosextra-carlito all 20130920-1.1 [743 kB]
# Fetched 743 kB in 1s (547 kB/s)
# Selecting previously unselected package fonts-crosextra-carlito.
# (Reading database ... 126308 files and directories currently installed.)
# Preparing to unpack .../fonts-crosextra-carlito_20130920-1.1_all.deb ...
# Unpacking fonts-crosextra-carlito (20130920-1.1) ...
# Setting up fonts-crosextra-carlito (20130920-1.1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %% [markdown]
# ##**Training Data**

# %%
SEED = 42
EPOCHS = 50
BATCH_SIZE = 16
IMG_HEIGHT = 512
IMG_WIDTH = 512

# %%
import keras_metrics as km

# %%
os.makedirs("/content/drive/My Drive/pap_smear/metrics", exist_ok=True)
os.makedirs("/content/drive/My Drive/pap_smear/preds", exist_ok=True)
os.makedirs("/content/drive/My Drive/pap_smear/models", exist_ok=True)

# %%
import os
import glob
import numpy as np
import tensorflow as tf
import cv2
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, roc_auc_score
import pandas as pd

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
import efficientnet.tfkeras as efn

# -----------------------------
# ✅ Data pipeline helpers
# -----------------------------
def parse_function(file_path, label):
    image = tf.io.read_file(file_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [512, 512])
    image = image / 255.0
    return image, label

def numpy_rotate(image):
    image = image.numpy()
    angle = np.random.uniform(-10, 10)
    h, w = image.shape[:2]
    M = cv2.getRotationMatrix2D((w/2, h/2), angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_LINEAR, borderMode=cv2.BORDER_REFLECT_101)
    return rotated.astype(np.float32)

def augment_function(image, label):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    do_rotate = tf.less(tf.random.uniform([], 0, 1.0), 0.5)

    def _rotate():
        rotated = tf.py_function(func=numpy_rotate, inp=[image], Tout=tf.float32)
        rotated.set_shape(image.shape)  # Very important!
        return rotated

    image = tf.cond(
        do_rotate,
        _rotate,
        lambda: image
    )

    image = tf.image.random_brightness(image, max_delta=0.1)
    return image, label

# -----------------------------
# ✅ Build your model
# -----------------------------
def build_model(img_height, img_width, n_channels):
    inp = Input(shape=(img_height, img_width, n_channels))
    base = efn.EfficientNetB0(
        input_shape=(img_height, img_width, n_channels),
        weights='imagenet',
        include_top=False
    )
    x = base(inp)
    x = GlobalAveragePooling2D()(x)
    out = Dense(4, activation='softmax')(x)
    model = Model(inputs=inp, outputs=out)
    return model

# -----------------------------
# ✅ Custom MetricsLogger callback (Option A)
# -----------------------------
class MetricsLogger(tf.keras.callbacks.Callback):
    def __init__(self, val_ds, val_labels, class_names, fold, out_csv):
        super(MetricsLogger, self).__init__()
        self.val_ds = val_ds
        self.val_labels = val_labels
        self.class_names = class_names
        self.fold = fold
        self.out_csv = out_csv
        self.df = pd.DataFrame(columns=['epoch','fold','metric','class','value'])

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        val_loss = logs.get('val_loss')
        self.df.loc[len(self.df)] = [epoch+1, self.fold, 'loss', 'overall', val_loss]

        y_true = self.val_labels
        y_pred_probs = self.model.predict(self.val_ds, verbose=0)
        y_pred = np.argmax(y_pred_probs, axis=1)

        acc = accuracy_score(y_true, y_pred)
        self.df.loc[len(self.df)] = [epoch+1, self.fold, 'accuracy', 'overall', acc]

        precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, labels=np.arange(len(self.class_names)))
        for idx, class_name in enumerate(self.class_names):
            self.df.loc[len(self.df)] = [epoch+1, self.fold, 'precision', class_name, precision[idx]]
            self.df.loc[len(self.df)] = [epoch+1, self.fold, 'recall', class_name, recall[idx]]
            self.df.loc[len(self.df)] = [epoch+1, self.fold, 'f1', class_name, f1[idx]]

        precision_macro, recall_macro, f1_macro, _ = precision_recall_fscore_support(y_true, y_pred, average='macro')
        self.df.loc[len(self.df)] = [epoch+1, self.fold, 'precision', 'overall', precision_macro]
        self.df.loc[len(self.df)] = [epoch+1, self.fold, 'recall', 'overall', recall_macro]
        self.df.loc[len(self.df)] = [epoch+1, self.fold, 'f1', 'overall', f1_macro]

        y_true_onehot = tf.keras.utils.to_categorical(y_true, num_classes=len(self.class_names))
        try:
            roc_auc_macro = roc_auc_score(y_true_onehot, y_pred_probs, average='macro', multi_class='ovr')
            self.df.loc[len(self.df)] = [epoch+1, self.fold, 'roc_auc', 'overall', roc_auc_macro]
            for idx, class_name in enumerate(self.class_names):
                roc_auc_class = roc_auc_score(y_true_onehot[:, idx], y_pred_probs[:, idx])
                self.df.loc[len(self.df)] = [epoch+1, self.fold, 'roc_auc', class_name, roc_auc_class]
        except:
            print(f"⚠️ Skipped ROC AUC at epoch {epoch+1} due to lack of class variation.")

        self.df.to_csv(self.out_csv, index=False)

    def on_train_end(self, logs=None):
        # ✅ Final predictions for McNemar's test
        y_true = self.val_labels
        y_pred_probs = self.model.predict(self.val_ds, verbose=0)
        y_pred = np.argmax(y_pred_probs, axis=1)

        val_preds_df = pd.DataFrame({
            'index': np.arange(len(y_true)),
            'true_label': y_true,
            'pred_label': y_pred
        })

        val_preds_df.to_csv(
            f'/content/drive/My Drive/pap_smear/preds/fold{self.fold}_preds_RGB.csv',
            index=False
        )
        print(f"✅ Saved final val predictions for fold {self.fold}")

# -----------------------------
# ✅ Loop over folds
# -----------------------------
base_path = "/content/drive/My Drive/pap_smear/folds"
class_names = ['NILM', 'LSIL', 'HSIL', 'SCC']

BUFFER_SIZE = 1000
BATCH_SIZE = 16

for fold in range(1, 5):
    print(f"\n📂 Starting Fold {fold}")

    train_paths, train_labels = [], []
    val_paths, val_labels = [], []

    for class_label in ['0', '1', '2', '3']:
        train_glob = glob.glob(os.path.join(base_path, f"fold{fold}/train/{class_label}/*"))
        val_glob = glob.glob(os.path.join(base_path, f"fold{fold}/val/{class_label}/*"))
        train_paths.extend(train_glob)
        val_paths.extend(val_glob)
        train_labels.extend([int(class_label)] * len(train_glob))
        val_labels.extend([int(class_label)] * len(val_glob))

    train_ds = (
        tf.data.Dataset.from_tensor_slices((train_paths, train_labels))
        .shuffle(BUFFER_SIZE)
        .map(parse_function, num_parallel_calls=tf.data.AUTOTUNE)
        .map(augment_function, num_parallel_calls=tf.data.AUTOTUNE)
        .batch(BATCH_SIZE)
        .prefetch(tf.data.AUTOTUNE)
    )

    val_ds = (
        tf.data.Dataset.from_tensor_slices((val_paths, val_labels))
        .map(parse_function, num_parallel_calls=tf.data.AUTOTUNE)
        .batch(BATCH_SIZE)
        .prefetch(tf.data.AUTOTUNE)
    )

    model = build_model(512, 512, 3)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-7, verbose=1)
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
    metrics_logger = MetricsLogger(
        val_ds=val_ds,
        val_labels=np.array(val_labels),
        class_names=class_names,
        fold=fold,
        out_csv = f"/content/drive/My Drive/pap_smear/metrics/metrics_fold{fold}.csv"
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=30,
        callbacks=[reduce_lr, early_stop, metrics_logger],
        verbose=1
    )

    model.save(f"/content/drive/My Drive/pap_smear/models/model_fold{fold}.h5")
    print(f"✅ Finished Fold {fold}")
# Out:
# 📂 Starting Fold 1
# Epoch 1/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 120s 1s/step - accuracy: 0.2754 - loss: 1.3929 - val_accuracy: 0.2490 - val_loss: 1.3529 - learning_rate: 1.0000e-05
# Epoch 2/30
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.7413 - loss: 1.1159 - val_accuracy: 0.1618 - val_loss: 1.7419 - learning_rate: 1.0000e-05
# Epoch 3/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.8418 - loss: 0.9178 - val_accuracy: 0.3154 - val_loss: 3.3676 - learning_rate: 1.0000e-05
# Epoch 4/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.8684 - loss: 0.7501
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 274ms/step - accuracy: 0.8681 - loss: 0.7492 - val_accuracy: 0.3900 - val_loss: 5.9995 - learning_rate: 1.0000e-05
# Epoch 5/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 273ms/step - accuracy: 0.8848 - loss: 0.6304 - val_accuracy: 0.3651 - val_loss: 5.0195 - learning_rate: 5.0000e-06
# Epoch 6/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 274ms/step - accuracy: 0.8803 - loss: 0.5912 - val_accuracy: 0.3651 - val_loss: 2.3857 - learning_rate: 5.0000e-06
# Epoch 7/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.8659 - loss: 0.5441
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 272ms/step - accuracy: 0.8665 - loss: 0.5433 - val_accuracy: 0.5104 - val_loss: 1.4091 - learning_rate: 5.0000e-06
# Epoch 8/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.8603 - loss: 0.5405 - val_accuracy: 0.6722 - val_loss: 0.8555 - learning_rate: 2.5000e-06
# Epoch 9/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 277ms/step - accuracy: 0.8860 - loss: 0.4632 - val_accuracy: 0.8880 - val_loss: 0.5934 - learning_rate: 2.5000e-06
# Epoch 10/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9075 - loss: 0.4507 - val_accuracy: 0.9295 - val_loss: 0.3934 - learning_rate: 2.5000e-06
# Epoch 11/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 278ms/step - accuracy: 0.9274 - loss: 0.4162 - val_accuracy: 0.9378 - val_loss: 0.3199 - learning_rate: 2.5000e-06
# Epoch 12/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.8910 - loss: 0.4335 - val_accuracy: 0.9378 - val_loss: 0.2915 - learning_rate: 2.5000e-06
# Epoch 13/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 277ms/step - accuracy: 0.9146 - loss: 0.3915 - val_accuracy: 0.9378 - val_loss: 0.2758 - learning_rate: 2.5000e-06
# Epoch 14/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9097 - loss: 0.3943 - val_accuracy: 0.9336 - val_loss: 0.2653 - learning_rate: 2.5000e-06
# Epoch 15/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 277ms/step - accuracy: 0.9324 - loss: 0.3412 - val_accuracy: 0.9419 - val_loss: 0.2555 - learning_rate: 2.5000e-06
# Epoch 16/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 274ms/step - accuracy: 0.9136 - loss: 0.3515 - val_accuracy: 0.9419 - val_loss: 0.2469 - learning_rate: 2.5000e-06
# Epoch 17/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9015 - loss: 0.3577 - val_accuracy: 0.9336 - val_loss: 0.2385 - learning_rate: 2.5000e-06
# Epoch 18/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9250 - loss: 0.3209 - val_accuracy: 0.9336 - val_loss: 0.2299 - learning_rate: 2.5000e-06
# Epoch 19/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.8965 - loss: 0.3638 - val_accuracy: 0.9336 - val_loss: 0.2227 - learning_rate: 2.5000e-06
# Epoch 20/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9223 - loss: 0.3143 - val_accuracy: 0.9419 - val_loss: 0.2143 - learning_rate: 2.5000e-06
# Epoch 21/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 274ms/step - accuracy: 0.9420 - loss: 0.2727 - val_accuracy: 0.9378 - val_loss: 0.2080 - learning_rate: 2.5000e-06
# Epoch 22/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9380 - loss: 0.2721 - val_accuracy: 0.9378 - val_loss: 0.2013 - learning_rate: 2.5000e-06
# Epoch 23/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 277ms/step - accuracy: 0.9151 - loss: 0.3023 - val_accuracy: 0.9419 - val_loss: 0.1955 - learning_rate: 2.5000e-06
# Epoch 24/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.9176 - loss: 0.2964 - val_accuracy: 0.9378 - val_loss: 0.1898 - learning_rate: 2.5000e-06
# Epoch 25/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.9438 - loss: 0.2795 - val_accuracy: 0.9378 - val_loss: 0.1848 - learning_rate: 2.5000e-06
# Epoch 26/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 274ms/step - accuracy: 0.9063 - loss: 0.2898 - val_accuracy: 0.9419 - val_loss: 0.1795 - learning_rate: 2.5000e-06
# Epoch 27/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.9481 - loss: 0.2297 - val_accuracy: 0.9461 - val_loss: 0.1753 - learning_rate: 2.5000e-06
# Epoch 28/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 278ms/step - accuracy: 0.9426 - loss: 0.2393 - val_accuracy: 0.9461 - val_loss: 0.1713 - learning_rate: 2.5000e-06
# Epoch 29/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 277ms/step - accuracy: 0.9362 - loss: 0.2241 - val_accuracy: 0.9502 - val_loss: 0.1675 - learning_rate: 2.5000e-06
# Epoch 30/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9321 - loss: 0.2466 - val_accuracy: 0.9461 - val_loss: 0.1627 - learning_rate: 2.5000e-06
# Restoring model weights from the end of the best epoch: 30.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Saved final val predictions for fold 1
# ✅ Finished Fold 1
#
# 📂 Starting Fold 2
# Epoch 1/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - accuracy: 0.3226 - loss: 1.3174 - val_accuracy: 0.1535 - val_loss: 1.6078 - learning_rate: 1.0000e-05
# Epoch 2/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 279ms/step - accuracy: 0.7697 - loss: 1.0596 - val_accuracy: 0.1992 - val_loss: 1.8429 - learning_rate: 1.0000e-05
# Epoch 3/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.8074 - loss: 0.8622 - val_accuracy: 0.2490 - val_loss: 3.9763 - learning_rate: 1.0000e-05
# Epoch 4/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.8612 - loss: 0.7081
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 274ms/step - accuracy: 0.8614 - loss: 0.7066 - val_accuracy: 0.3734 - val_loss: 6.1092 - learning_rate: 1.0000e-05
# Epoch 5/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 273ms/step - accuracy: 0.8816 - loss: 0.6107 - val_accuracy: 0.3734 - val_loss: 7.6076 - learning_rate: 5.0000e-06
# Epoch 6/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 272ms/step - accuracy: 0.8946 - loss: 0.5294 - val_accuracy: 0.3527 - val_loss: 2.5061 - learning_rate: 5.0000e-06
# Epoch 7/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.8883 - loss: 0.4951 - val_accuracy: 0.5560 - val_loss: 1.1184 - learning_rate: 5.0000e-06
# Epoch 8/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.8888 - loss: 0.4642 - val_accuracy: 0.7261 - val_loss: 0.7443 - learning_rate: 5.0000e-06
# Epoch 9/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.9021 - loss: 0.4434 - val_accuracy: 0.9253 - val_loss: 0.4671 - learning_rate: 5.0000e-06
# Epoch 10/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 277ms/step - accuracy: 0.9077 - loss: 0.3950 - val_accuracy: 0.9336 - val_loss: 0.2915 - learning_rate: 5.0000e-06
# Epoch 11/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 277ms/step - accuracy: 0.8975 - loss: 0.3627 - val_accuracy: 0.9378 - val_loss: 0.2417 - learning_rate: 5.0000e-06
# Epoch 12/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 278ms/step - accuracy: 0.9157 - loss: 0.3418 - val_accuracy: 0.9461 - val_loss: 0.2171 - learning_rate: 5.0000e-06
# Epoch 13/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.9101 - loss: 0.3461 - val_accuracy: 0.9502 - val_loss: 0.2008 - learning_rate: 5.0000e-06
# Epoch 14/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9304 - loss: 0.2843 - val_accuracy: 0.9585 - val_loss: 0.1886 - learning_rate: 5.0000e-06
# Epoch 15/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 274ms/step - accuracy: 0.9174 - loss: 0.2927 - val_accuracy: 0.9585 - val_loss: 0.1778 - learning_rate: 5.0000e-06
# Epoch 16/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 273ms/step - accuracy: 0.9420 - loss: 0.2621 - val_accuracy: 0.9627 - val_loss: 0.1665 - learning_rate: 5.0000e-06
# Epoch 17/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.9090 - loss: 0.2866 - val_accuracy: 0.9668 - val_loss: 0.1585 - learning_rate: 5.0000e-06
# Epoch 18/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9352 - loss: 0.2310 - val_accuracy: 0.9710 - val_loss: 0.1492 - learning_rate: 5.0000e-06
# Epoch 19/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.9584 - loss: 0.2183 - val_accuracy: 0.9710 - val_loss: 0.1413 - learning_rate: 5.0000e-06
# Epoch 20/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9417 - loss: 0.2278 - val_accuracy: 0.9710 - val_loss: 0.1331 - learning_rate: 5.0000e-06
# Epoch 21/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 274ms/step - accuracy: 0.9425 - loss: 0.2041 - val_accuracy: 0.9710 - val_loss: 0.1267 - learning_rate: 5.0000e-06
# Epoch 22/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9423 - loss: 0.2039 - val_accuracy: 0.9710 - val_loss: 0.1205 - learning_rate: 5.0000e-06
# Epoch 23/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 274ms/step - accuracy: 0.9398 - loss: 0.1967 - val_accuracy: 0.9751 - val_loss: 0.1132 - learning_rate: 5.0000e-06
# Epoch 24/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9546 - loss: 0.1672 - val_accuracy: 0.9793 - val_loss: 0.1075 - learning_rate: 5.0000e-06
# Epoch 25/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9452 - loss: 0.1875 - val_accuracy: 0.9793 - val_loss: 0.1020 - learning_rate: 5.0000e-06
# Epoch 26/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.9592 - loss: 0.1934 - val_accuracy: 0.9751 - val_loss: 0.0963 - learning_rate: 5.0000e-06
# Epoch 27/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 274ms/step - accuracy: 0.9577 - loss: 0.1772 - val_accuracy: 0.9751 - val_loss: 0.0925 - learning_rate: 5.0000e-06
# Epoch 28/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.9565 - loss: 0.1719 - val_accuracy: 0.9751 - val_loss: 0.0879 - learning_rate: 5.0000e-06
# Epoch 29/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9671 - loss: 0.1506 - val_accuracy: 0.9834 - val_loss: 0.0832 - learning_rate: 5.0000e-06
# Epoch 30/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 277ms/step - accuracy: 0.9705 - loss: 0.1294 - val_accuracy: 0.9834 - val_loss: 0.0796 - learning_rate: 5.0000e-06
# Restoring model weights from the end of the best epoch: 30.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Saved final val predictions for fold 2
# ✅ Finished Fold 2
#
# 📂 Starting Fold 3
# Epoch 1/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 167s 2s/step - accuracy: 0.2107 - loss: 1.4681 - val_accuracy: 0.2292 - val_loss: 1.4737 - learning_rate: 1.0000e-05
# Epoch 2/30
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.5298 - loss: 1.2326 - val_accuracy: 0.1708 - val_loss: 2.2164 - learning_rate: 1.0000e-05
# Epoch 3/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.8094 - loss: 0.9969 - val_accuracy: 0.2708 - val_loss: 3.4330 - learning_rate: 1.0000e-05
# Epoch 4/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.8555 - loss: 0.8259
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.8558 - loss: 0.8241 - val_accuracy: 0.4042 - val_loss: 5.5423 - learning_rate: 1.0000e-05
# Epoch 5/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.8716 - loss: 0.6743 - val_accuracy: 0.3375 - val_loss: 4.1799 - learning_rate: 5.0000e-06
# Epoch 6/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 272ms/step - accuracy: 0.9062 - loss: 0.5942 - val_accuracy: 0.4250 - val_loss: 2.4701 - learning_rate: 5.0000e-06
# Epoch 7/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.8986 - loss: 0.5430 - val_accuracy: 0.5958 - val_loss: 1.1435 - learning_rate: 5.0000e-06
# Epoch 8/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9070 - loss: 0.4990 - val_accuracy: 0.7375 - val_loss: 0.7958 - learning_rate: 5.0000e-06
# Epoch 9/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.9022 - loss: 0.4404 - val_accuracy: 0.8958 - val_loss: 0.5320 - learning_rate: 5.0000e-06
# Epoch 10/30
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 278ms/step - accuracy: 0.9141 - loss: 0.4021 - val_accuracy: 0.9125 - val_loss: 0.3307 - learning_rate: 5.0000e-06
# Epoch 11/30
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9119 - loss: 0.4053 - val_accuracy: 0.9167 - val_loss: 0.2774 - learning_rate: 5.0000e-06
# Epoch 12/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9193 - loss: 0.3516 - val_accuracy: 0.9167 - val_loss: 0.2415 - learning_rate: 5.0000e-06
# Epoch 13/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 274ms/step - accuracy: 0.9115 - loss: 0.3352 - val_accuracy: 0.9292 - val_loss: 0.2188 - learning_rate: 5.0000e-06
# Epoch 14/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 277ms/step - accuracy: 0.9202 - loss: 0.3176 - val_accuracy: 0.9417 - val_loss: 0.2021 - learning_rate: 5.0000e-06
# Epoch 15/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.9365 - loss: 0.2906 - val_accuracy: 0.9583 - val_loss: 0.1893 - learning_rate: 5.0000e-06
# Epoch 16/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 272ms/step - accuracy: 0.9367 - loss: 0.2699 - val_accuracy: 0.9708 - val_loss: 0.1755 - learning_rate: 5.0000e-06
# Epoch 17/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 274ms/step - accuracy: 0.9467 - loss: 0.2711 - val_accuracy: 0.9750 - val_loss: 0.1611 - learning_rate: 5.0000e-06
# Epoch 18/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 279ms/step - accuracy: 0.9241 - loss: 0.2709 - val_accuracy: 0.9792 - val_loss: 0.1512 - learning_rate: 5.0000e-06
# Epoch 19/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.9386 - loss: 0.2311 - val_accuracy: 0.9750 - val_loss: 0.1437 - learning_rate: 5.0000e-06
# Epoch 20/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 273ms/step - accuracy: 0.9318 - loss: 0.2474 - val_accuracy: 0.9833 - val_loss: 0.1356 - learning_rate: 5.0000e-06
# Epoch 21/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 278ms/step - accuracy: 0.9261 - loss: 0.2382 - val_accuracy: 0.9833 - val_loss: 0.1269 - learning_rate: 5.0000e-06
# Epoch 22/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 274ms/step - accuracy: 0.9502 - loss: 0.2109 - val_accuracy: 0.9917 - val_loss: 0.1178 - learning_rate: 5.0000e-06
# Epoch 23/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 274ms/step - accuracy: 0.9348 - loss: 0.2173 - val_accuracy: 0.9917 - val_loss: 0.1112 - learning_rate: 5.0000e-06
# Epoch 24/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9534 - loss: 0.2111 - val_accuracy: 0.9958 - val_loss: 0.1032 - learning_rate: 5.0000e-06
# Epoch 25/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9479 - loss: 0.2018 - val_accuracy: 0.9958 - val_loss: 0.0961 - learning_rate: 5.0000e-06
# Epoch 26/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.9469 - loss: 0.2052 - val_accuracy: 0.9958 - val_loss: 0.0900 - learning_rate: 5.0000e-06
# Epoch 27/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.9568 - loss: 0.1722 - val_accuracy: 1.0000 - val_loss: 0.0864 - learning_rate: 5.0000e-06
# Epoch 28/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 277ms/step - accuracy: 0.9601 - loss: 0.1682 - val_accuracy: 1.0000 - val_loss: 0.0822 - learning_rate: 5.0000e-06
# Epoch 29/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.9603 - loss: 0.1790 - val_accuracy: 1.0000 - val_loss: 0.0765 - learning_rate: 5.0000e-06
# Epoch 30/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.9716 - loss: 0.1286 - val_accuracy: 1.0000 - val_loss: 0.0726 - learning_rate: 5.0000e-06
# Restoring model weights from the end of the best epoch: 30.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Saved final val predictions for fold 3
# ✅ Finished Fold 3
#
# 📂 Starting Fold 4
# Epoch 1/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.1938 - loss: 1.3883 - val_accuracy: 0.4458 - val_loss: 1.3621 - learning_rate: 1.0000e-05
# Epoch 2/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 278ms/step - accuracy: 0.5948 - loss: 1.1391 - val_accuracy: 0.2250 - val_loss: 1.6156 - learning_rate: 1.0000e-05
# Epoch 3/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 288ms/step - accuracy: 0.8236 - loss: 0.9216 - val_accuracy: 0.2417 - val_loss: 5.2144 - learning_rate: 1.0000e-05
# Epoch 4/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.8938 - loss: 0.7351
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.8939 - loss: 0.7332 - val_accuracy: 0.2875 - val_loss: 9.2188 - learning_rate: 1.0000e-05
# Epoch 5/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9080 - loss: 0.6263 - val_accuracy: 0.2750 - val_loss: 7.4064 - learning_rate: 5.0000e-06
# Epoch 6/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 273ms/step - accuracy: 0.8890 - loss: 0.5799 - val_accuracy: 0.4125 - val_loss: 3.1957 - learning_rate: 5.0000e-06
# Epoch 7/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9157 - loss: 0.4982 - val_accuracy: 0.5250 - val_loss: 1.2175 - learning_rate: 5.0000e-06
# Epoch 8/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 277ms/step - accuracy: 0.9147 - loss: 0.4473 - val_accuracy: 0.6625 - val_loss: 0.9303 - learning_rate: 5.0000e-06
# Epoch 9/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9167 - loss: 0.4156 - val_accuracy: 0.9042 - val_loss: 0.5206 - learning_rate: 5.0000e-06
# Epoch 10/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 278ms/step - accuracy: 0.9057 - loss: 0.4155 - val_accuracy: 0.9458 - val_loss: 0.3161 - learning_rate: 5.0000e-06
# Epoch 11/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 278ms/step - accuracy: 0.8963 - loss: 0.3815 - val_accuracy: 0.9500 - val_loss: 0.2564 - learning_rate: 5.0000e-06
# Epoch 12/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 278ms/step - accuracy: 0.9345 - loss: 0.3258 - val_accuracy: 0.9500 - val_loss: 0.2317 - learning_rate: 5.0000e-06
# Epoch 13/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 277ms/step - accuracy: 0.9297 - loss: 0.3197 - val_accuracy: 0.9542 - val_loss: 0.2134 - learning_rate: 5.0000e-06
# Epoch 14/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9040 - loss: 0.3172 - val_accuracy: 0.9583 - val_loss: 0.1981 - learning_rate: 5.0000e-06
# Epoch 15/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 278ms/step - accuracy: 0.9076 - loss: 0.3250 - val_accuracy: 0.9625 - val_loss: 0.1851 - learning_rate: 5.0000e-06
# Epoch 16/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9352 - loss: 0.2682 - val_accuracy: 0.9625 - val_loss: 0.1750 - learning_rate: 5.0000e-06
# Epoch 17/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 277ms/step - accuracy: 0.9205 - loss: 0.2784 - val_accuracy: 0.9708 - val_loss: 0.1640 - learning_rate: 5.0000e-06
# Epoch 18/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 280ms/step - accuracy: 0.9514 - loss: 0.2209 - val_accuracy: 0.9667 - val_loss: 0.1543 - learning_rate: 5.0000e-06
# Epoch 19/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 279ms/step - accuracy: 0.9453 - loss: 0.2329 - val_accuracy: 0.9750 - val_loss: 0.1454 - learning_rate: 5.0000e-06
# Epoch 20/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 278ms/step - accuracy: 0.9361 - loss: 0.2233 - val_accuracy: 0.9792 - val_loss: 0.1372 - learning_rate: 5.0000e-06
# Epoch 21/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 278ms/step - accuracy: 0.9455 - loss: 0.2244 - val_accuracy: 0.9792 - val_loss: 0.1305 - learning_rate: 5.0000e-06
# Epoch 22/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.9543 - loss: 0.1897 - val_accuracy: 0.9750 - val_loss: 0.1244 - learning_rate: 5.0000e-06
# Epoch 23/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 277ms/step - accuracy: 0.9569 - loss: 0.1988 - val_accuracy: 0.9750 - val_loss: 0.1180 - learning_rate: 5.0000e-06
# Epoch 24/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 277ms/step - accuracy: 0.9551 - loss: 0.1780 - val_accuracy: 0.9792 - val_loss: 0.1113 - learning_rate: 5.0000e-06
# Epoch 25/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 278ms/step - accuracy: 0.9468 - loss: 0.2130 - val_accuracy: 0.9833 - val_loss: 0.1065 - learning_rate: 5.0000e-06
# Epoch 26/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 279ms/step - accuracy: 0.9673 - loss: 0.1566 - val_accuracy: 0.9833 - val_loss: 0.1014 - learning_rate: 5.0000e-06
# Epoch 27/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 277ms/step - accuracy: 0.9749 - loss: 0.1588 - val_accuracy: 0.9875 - val_loss: 0.0970 - learning_rate: 5.0000e-06
# Epoch 28/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 277ms/step - accuracy: 0.9758 - loss: 0.1507 - val_accuracy: 0.9875 - val_loss: 0.0922 - learning_rate: 5.0000e-06
# Epoch 29/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 276ms/step - accuracy: 0.9568 - loss: 0.1539 - val_accuracy: 0.9875 - val_loss: 0.0866 - learning_rate: 5.0000e-06
# Epoch 30/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 277ms/step - accuracy: 0.9734 - loss: 0.1350 - val_accuracy: 0.9875 - val_loss: 0.0835 - learning_rate: 5.0000e-06
# Restoring model weights from the end of the best epoch: 30.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Saved final val predictions for fold 4
# ✅ Finished Fold 4

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib as mpl

# === ✅ Add Carlito font correctly ===
font_path = '/usr/share/fonts/truetype/crosextra/Carlito-Regular.ttf'
fm.fontManager.addfont(font_path)
mpl.rcParams['font.family'] = 'Carlito'

# === Load all folds ===
dfs = []
for fold in range(1, 5):
    df = pd.read_csv(f'/content/drive/My Drive/pap_smear/metrics/metrics_fold{fold}.csv')
    df['fold'] = fold
    dfs.append(df)

full_df = pd.concat(dfs, ignore_index=True)

# === Metrics you want ===
metrics = ['accuracy', 'f1', 'loss', 'roc_auc']

for metric in metrics:
    plt.figure(figsize=(8, 5))

    # Filter for overall only
    metric_df = full_df[(full_df['metric'] == metric) & (full_df['class'] == 'overall')]

    for fold in metric_df['fold'].unique():
        fold_df = metric_df[metric_df['fold'] == fold]
        plt.plot(fold_df['epoch'], fold_df['value'], label=f'Fold {fold}')

    plt.title(f'Validation {metric.capitalize()} Across Epochs', fontsize=14)
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel(metric.capitalize(), fontsize=12)
    plt.legend(title='Fold', fontsize=10)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib as mpl

# === ✅ Add Carlito font correctly ===
font_path = '/usr/share/fonts/truetype/crosextra/Carlito-Regular.ttf'
fm.fontManager.addfont(font_path)
mpl.rcParams['font.family'] = 'Carlito'

# === Load all folds ===
dfs = []
for fold in range(1, 5):
    df = pd.read_csv(f'/content/drive/My Drive/pap_smear/metrics/metrics_fold{fold}.csv')
    df['fold'] = fold
    dfs.append(df)

full_df = pd.concat(dfs, ignore_index=True)

# === Metric you want ===
metrics = ['accuracy', 'f1', 'loss', 'roc_auc']

# NYU purple color
nyu_purple = '#57068c'

for metric in metrics:
    plt.figure(figsize=(8, 5))

    metric_df = full_df[(full_df['metric'] == metric) & (full_df['class'] == 'overall')]
    mean_df = metric_df.groupby('epoch')['value'].mean().reset_index()

    plt.plot(
        mean_df['epoch'],
        mean_df['value'],
        '-',                  # solid line, no markers
        color=nyu_purple,
        label='Mean'
    )

    plt.title(f'Validation {metric.capitalize()} (Mean Across Folds)', fontsize=14)
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel(metric.capitalize(), fontsize=12)
    plt.legend(fontsize=10)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ##**Evaluation Metrics**

# %%
import pandas as pd

# === Load all metrics ===
dfs = []
for fold in range(1, 5):
    df = pd.read_csv(f'/content/drive/My Drive/pap_smear/metrics/metrics_fold{fold}.csv')
    df['fold'] = fold
    dfs.append(df)

full_df = pd.concat(dfs, ignore_index=True)

# === Filter only final epoch for each fold ===
# If you want best epoch per fold, you’d do:
# final_df = full_df.loc[full_df.groupby('fold')['epoch'].idxmax()]

# Here: get final epoch for each fold
fold_results = []

for fold in range(1, 6):
    fold_df = full_df[full_df['fold'] == fold]
    final_epoch = fold_df['epoch'].max()
    final_df = fold_df[fold_df['epoch'] == final_epoch]
    fold_results.append(final_df)

final_df = pd.concat(fold_results, ignore_index=True)

# === Keep only precision, recall, f1 for per-class ===
results = final_df[
    (final_df['metric'].isin(['precision', 'recall', 'f1'])) &
    (final_df['class'].isin(['NILM', 'LSIL', 'HSIL', 'SCC']))
]

# === Pivot to get [fold x metric] for each class ===
table = []
classes = ['NILM', 'LSIL', 'HSIL', 'SCC']
for class_name in classes:
    class_data = results[results['class'] == class_name].pivot(
        index='metric', columns='fold', values='value'
    )
    mean = class_data.mean(axis=1)
    std = class_data.std(axis=1)
    # You can skip std if you don’t want it
    table.append({
        'Class': class_name,
        'Precision': f"{mean['precision']:.5f}",
        'Recall': f"{mean['recall']:.5f}",
        'F1-score': f"{mean['f1']:.5f}",
        'Precision_std': f"{std['precision']:.5f}",
        'Recall_std': f"{std['recall']:.5f}",
        'F1-score_std': f"{std['f1']:.5f}"
    })

summary_df = pd.DataFrame(table)
print(summary_df)

# === Optional: save to CSV ===
summary_df.to_csv('/content/drive/My Drive/pap_smear/final_class_metrics.csv', index=False)
# Out:
#   Class Precision   Recall F1-score Precision_std Recall_std F1-score_std
# 0  NILM   0.99838  1.00000  0.99919       0.00325    0.00000      0.00163
# 1  LSIL   0.98387  1.00000  0.99167       0.03226    0.00000      0.01667
# 2  HSIL   0.94928  0.93796  0.94312       0.04792    0.07789      0.06085
# 3   SCC   0.88391  0.86769  0.87500       0.15826    0.13870      0.14611

# %%
import pandas as pd

# === Load all metrics ===
dfs = []
for fold in range(1, 5):  # fix range to 1-6 if you have 5 folds!
    df = pd.read_csv(f'/content/drive/My Drive/pap_smear/metrics/metrics_fold{fold}.csv')
    df['fold'] = fold
    dfs.append(df)

full_df = pd.concat(dfs, ignore_index=True)

# === Get final epoch for each fold ===
fold_results = []
for fold in range(1, 5):
    fold_df = full_df[full_df['fold'] == fold]
    final_epoch = fold_df['epoch'].max()
    final_df = fold_df[fold_df['epoch'] == final_epoch]
    fold_results.append(final_df)

final_df = pd.concat(fold_results, ignore_index=True)

# === Keep only per-class metrics ===
results = final_df[
    (final_df['metric'].isin(['precision', 'recall', 'f1'])) &
    (final_df['class'].isin(['NILM', 'LSIL', 'HSIL', 'SCC']))
]

# === Pivot, compute mean ± std, and format ===
table = []
classes = ['NILM', 'LSIL', 'HSIL', 'SCC']
for class_name in classes:
    class_data = results[results['class'] == class_name].pivot(
        index='metric', columns='fold', values='value'
    )
    mean = class_data.mean(axis=1)
    std = class_data.std(axis=1)

    table.append({
        'Class': class_name,
        'Precision': f"{mean['precision']:.3f} ± {std['precision']:.3f}",
        'Recall': f"{mean['recall']:.3f} ± {std['recall']:.3f}",
        'F1-score': f"{mean['f1']:.3f} ± {std['f1']:.3f}"
    })

summary_df = pd.DataFrame(table)
print(summary_df)

# === Optional: save for your paper ===
summary_df.to_csv('/content/drive/My Drive/pap_smear/final_class_metrics_formatted.csv', index=False)
# Out:
#   Class      Precision         Recall       F1-score
# 0  NILM  0.998 ± 0.003  1.000 ± 0.000  0.999 ± 0.002
# 1  LSIL  0.984 ± 0.032  1.000 ± 0.000  0.992 ± 0.017
# 2  HSIL  0.949 ± 0.048  0.938 ± 0.078  0.943 ± 0.061
# 3   SCC  0.884 ± 0.158  0.868 ± 0.139  0.875 ± 0.146

# %%
import pandas as pd

# === Load all folds ===
dfs = []
for fold in range(1, 5):   # ✅ use 1–5 for 4 folds!
    df = pd.read_csv(f'/content/drive/My Drive/pap_smear/metrics/metrics_fold{fold}.csv')
    df['fold'] = fold
    dfs.append(df)

full_df = pd.concat(dfs, ignore_index=True)

# === Filter for overall only at final epoch ===
overall_results = []
for fold in range(1, 5):   # ✅ 4 folds!
    fold_df = full_df[full_df['fold'] == fold]
    final_epoch = fold_df['epoch'].max()
    final_df = fold_df[
        (fold_df['epoch'] == final_epoch) &
        (fold_df['class'] == 'overall') &
        (fold_df['metric'].isin(['accuracy', 'loss', 'precision', 'recall', 'f1', 'roc_auc']))
    ]
    overall_results.append(final_df)

overall_df = pd.concat(overall_results, ignore_index=True)

# === Compute mean ± SD for each metric ===
overall_table = []
metrics = ['accuracy', 'loss', 'precision', 'recall', 'f1', 'roc_auc']
for metric in metrics:
    metric_vals = overall_df[overall_df['metric'] == metric]['value'].values
    mean_val = metric_vals.mean()
    std_val = metric_vals.std()
    overall_table.append({
        'Metric': metric.capitalize(),
        'Mean ± SD': f"{mean_val:.3f} ± {std_val:.3f}"
    })

summary_overall_df = pd.DataFrame(overall_table)

# ✅ Display
print(summary_overall_df)

# ✅ Optional: save
summary_overall_df.to_csv('/content/drive/My Drive/pap_smear/final_overall_metrics_formatted.csv', index=False)
# Out:
#       Metric      Mean ± SD
# 0   Accuracy  0.979 ± 0.020
# 1       Loss  0.100 ± 0.037
# 2  Precision  0.954 ± 0.050
# 3     Recall  0.951 ± 0.046
# 4         F1  0.952 ± 0.048
# 5    Roc_auc  0.997 ± 0.003

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

# === Settings ===
folds = [1, 2, 3, 4]
class_names = ['NILM', 'LSIL', 'HSIL', 'SCC']
n_classes = len(class_names)

# === Initialize total confusion matrix
cm_total = np.zeros((n_classes, n_classes), dtype=int)

# === Loop through folds and sum up
for fold in folds:
    df = pd.read_csv(f'/content/drive/My Drive/pap_smear/preds/fold{fold}_preds_RGB.csv')
    y_true = df['true_label']
    y_pred = df['pred_label']
    cm = confusion_matrix(y_true, y_pred, labels=range(n_classes))
    cm_total += cm

# === Display combined confusion matrix
ConfusionMatrixDisplay(cm_total, display_labels=class_names).plot(
    cmap=plt.cm.Blues, values_format='d'
)
plt.title("Confusion Matrix - All 4 Folds Combined")
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix

folds = [1, 2, 3, 4]
class_names = ['NILM', 'LSIL', 'HSIL', 'SCC']
n_classes = len(class_names)

# === Store all folds ===
results = []

for fold in folds:
    df = pd.read_csv(f'/content/drive/My Drive/pap_smear/preds/fold{fold}_preds_RGB.csv')
    y_true = df['true_label']
    y_pred = df['pred_label']
    cm = confusion_matrix(y_true, y_pred, labels=range(n_classes))

    # Per class:
    for i, class_name in enumerate(class_names):
        TP = cm[i, i]
        FN = cm[i, :].sum() - TP
        FP = cm[:, i].sum() - TP
        TN = cm.sum() - (TP + FP + FN)

        sensitivity = TP / (TP + FN) if (TP + FN) > 0 else 0
        specificity = TN / (TN + FP) if (TN + FP) > 0 else 0

        results.append({
            'fold': fold,
            'class': class_name,
            'sensitivity': sensitivity,
            'specificity': specificity
        })

# === Make dataframe ===
sens_spec_df = pd.DataFrame(results)

print("\n🔍 Per class, per fold:")
print(sens_spec_df.head())

# === Compute mean ± SD across folds ===
summary = []
for class_name in class_names:
    class_df = sens_spec_df[sens_spec_df['class'] == class_name]

    sens_mean = class_df['sensitivity'].mean()
    sens_std = class_df['sensitivity'].std()

    spec_mean = class_df['specificity'].mean()
    spec_std = class_df['specificity'].std()

    summary.append({
        'class': class_name,
        'sensitivity': f"{sens_mean:.3f} ± {sens_std:.3f}",
        'specificity': f"{spec_mean:.3f} ± {spec_std:.3f}",
    })

summary_df = pd.DataFrame(summary)

print("\n✅ Mean ± SD across folds:")
print(summary_df)

# === Save if you want ===
sens_spec_df.to_csv('/content/drive/My Drive/pap_smear/sens_spec_per_fold.csv', index=False)
summary_df.to_csv('/content/drive/My Drive/pap_smear/sens_spec_mean_sd.csv', index=False)
# Out:
# 🔍 Per class, per fold:
#    fold class  sensitivity  specificity
# 0     1  NILM     1.000000     1.000000
# 1     1  LSIL     1.000000     0.990566
# 2     1  HSIL     0.825000     0.980100
# 3     1   SCC     0.684211     0.968468
# 4     2  NILM     1.000000     1.000000
#
# ✅ Mean ± SD across folds:
#   class    sensitivity    specificity
# 0  NILM  1.000 ± 0.000  0.997 ± 0.006
# 1  LSIL  1.000 ± 0.000  0.998 ± 0.005
# 2  HSIL  0.938 ± 0.078  0.990 ± 0.009
# 3   SCC  0.868 ± 0.139  0.990 ± 0.014

# %%
import pandas as pd
from sklearn.metrics import cohen_kappa_score

folds = [1, 2, 3, 4]

kappa_results = []

for fold in folds:
    df = pd.read_csv(f'/content/drive/My Drive/pap_smear/preds/fold{fold}_preds_RGB.csv')
    y_true = df['true_label']
    y_pred = df['pred_label']

    kappa = cohen_kappa_score(y_true, y_pred)
    kappa_results.append({'fold': fold, 'cohen_kappa': kappa})

kappa_df = pd.DataFrame(kappa_results)
print("\n✅ Cohen’s Kappa per fold:")
print(kappa_df)
# Out:
# ✅ Cohen’s Kappa per fold:
#    fold  cohen_kappa
# 0     1     0.901827
# 1     2     0.969687
# 2     3     1.000000
# 3     4     0.976989

# %%
mean_kappa = kappa_df['cohen_kappa'].mean()
std_kappa = kappa_df['cohen_kappa'].std()

print(f"\n✅ Overall Cohen’s Kappa: {mean_kappa:.3f} ± {std_kappa:.3f}")

# Save if you like
kappa_df.to_csv('/content/drive/My Drive/pap_smear/cohen_kappa_per_fold.csv', index=False)
with open('/content/drive/My Drive/pap_smear/cohen_kappa_summary.txt', 'w') as f:
    f.write(f"Cohen’s Kappa mean ± SD: {mean_kappa:.3f} ± {std_kappa:.3f}\n")
# Out:
# ✅ Overall Cohen’s Kappa: 0.962 ± 0.042

# %%
import numpy as np

dfs = []
for fold in folds:
    df = pd.read_csv(f'/content/drive/My Drive/pap_smear/preds/fold{fold}_preds_RGB.csv')
    dfs.append(df)

combined_df = pd.concat(dfs, ignore_index=True)
y_true_all = combined_df['true_label']
y_pred_all = combined_df['pred_label']

kappa_overall = cohen_kappa_score(y_true_all, y_pred_all)
print(f"\n✅ Cohen’s Kappa (all folds combined): {kappa_overall:.3f}")
# Out:
# ✅ Cohen’s Kappa (all folds combined): 0.962
